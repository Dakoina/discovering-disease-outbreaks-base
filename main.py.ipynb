# %% [markdown]
# # Discovering disease outbreaks
# ## 1. extracting city & country data from news headlines
# - analyse and identify potential problems in of the data
# - normalize headlines and remove accents marks (unidecode)
# - optimize where possible

# %%
from unidecode import unidecode
import geonamescache
import re
import timeit
import pandas as pd

# %%
# get and decode the headlines
headlines=[]
with open('data\headlines.txt', 'r') as dirty_headlines:
    for line in dirty_headlines:
        headlines.append(unidecode(line.strip()))

# %%
# let's check the difference
if len(headlines) != len(set(headlines)):
    print(f'The list of headlines does contain doubles. ' +
          f'\n# headlines: {len(headlines)}, converted to set we have {len(set(headlines))}')
    
# using a dict, we lose some precision
# Out:
# The list of headlines does contain doubles.
# # headlines: 650, converted to set we have 647

# %%
# load geo data
gc = geonamescache.GeonamesCache()
countries = gc.get_countries_by_names()
cities = gc.get_cities()

# %%
# some test/verification methods

def cities_contains(search: str) -> bool:
    # does the cities list contain the given city?
    for city in cities.values():
        if search in city.get("name"):
            return True
    return False

def countries_contains(search: str) -> bool:
    # does the countries list contain the searched country
    return search in countries

# %% [markdown]
# **The first version of the script needed about *1000sec* to execute and required a better approach:**

# %%
result = []


def analyse_data():
    #analyse all headlines

    for headline in headlines:
        print(f'Current headline: "{headline}"')

        result_country = None

        # let's test the countries
        for country in countries:
            # make regex (compiled version probably doesnt do much in this case)
            regex = '\\b'+unidecode(country)+'\\b'
            compiled_regex = re.compile(regex)
            match = compiled_regex.search(headline)
            if match:
                result_country = country
                print(f' - country: {country}')
                break

        resulted_city = None

        # let's test cities
        for city in cities.values():
            # make regex
            current_city = unidecode(city.get('name'))
            regex = '\\b' + current_city + '\\b'
            compiled_regex = re.compile(regex)
            match = compiled_regex.search(headline)
            if match:
                if resulted_city is None or len(current_city) > len(resulted_city):
                    resulted_city = current_city

        print(f' - city: {resulted_city}') 

        #add the data to the result list
        result.append([headline, result_country, resulted_city])
        
print("skipping v1 ...")
# execution_time = timeit.timeit(analyse_data, number=1)
# print(execution_time)
# Out:
# skipping v1 ...

# %%
result_v2 = [[headline, None, None] for headline in headlines]

def analyse_data_v2():
    
    #analyse all countries in the headlines
    for country in countries:
        # compile regex for faster checking, match complete "words"
        regex = '\\b' + country + '\\b'
        compiled_regex = re.compile(regex)

        # search country in headline
        for headline_item in result_v2:
            match = compiled_regex.search(headline_item[0])
            if match:
                headline_item[1] = country
                print(f'Found country "{country}" in headline: "{headline_item[0]}"')
                break
    
    #analyse all cities appearing in the headlines
    for city in cities.values():
        current_city = city.get('name')

        # compile regex for faster checking, match complete "words"
        regex = '\\b' + current_city + '\\b'
        compiled_regex = re.compile(regex)

        for headline_item in result_v2:
            match = compiled_regex.search(headline_item[0])  # best not to use "ignore case" for cases like "Goes" and "Of"
            if match:
                # if there are multiple cities in a headline, we pick the larger length city as "New York City" takes
                # precedence over "York"
                if headline_item[2] is None:
                    headline_item[2] = current_city
                    print(f'Found city: "{current_city}" in "{headline_item[0]}"')
                elif len(headline_item[2]) < len(current_city):
                    print(f'Replacing previously found city "{headline_item[2]}" in "{headline_item[0]}" with "{current_city}"')
                    headline_item[2] = current_city

execution_time = timeit.timeit(analyse_data_v2, number=1)
print(f'\nExecuted v2 in {execution_time} seconds')
                
# print(result_v2)
# Out:
# Found country "Brazil" in headline: "Mystery Virus Spreads in Recife, Brazil"
# Found country "Belize" in headline: "Belize City under threat from Zika"
# Found country "Guatemala" in headline: "Rumors about Meningitis spreading in Guatemala City have been refuted"
# Found country "Hong Kong" in headline: "Norovirus Exposure in Hong Kong"
# Found country "Mexico" in headline: "Zika outbreak spreads to Mexico City"
# Found country "Malaysia" in headline: "Zika surfaces in Klang, Malaysia"
# Found country "Panama" in headline: "Outbreak of Zika in Panama City"
# Found country "Singapore" in headline: "Zika cases in Singapore reach 393"
# Found country "Thailand" in headline: "Thailand-Zika Virus in Bangkok"
# Found country "Vietnam" in headline: "Zika cases in Vietnam's Ho Chi Minh City surge"
# Found city: "Dubai" in "Authorities are Worried about the Spread of Norovirus in Dubai"
# Found city: "Yerevan" in "West Nile Virus Symptoms Spread all over Yerevan"
# Found city: "Luanda" in "Tuberculosis Hits Luanda"
# Found city: "Santa Elena" in "Outbreak of Zika in Santa Elena"
# Found city: "La Paz" in "Will Hepatitis B vaccine help La Paz?"
# Found city: "Buenos Aires" in "Authorities are Worried about the Spread of Norovirus in Buenos Aires"
# Found city: "Santa Rosa" in "Hepatitis E re-emerges in Santa Rosa"
# Found city: "Santa Fe" in "Bronchitis Symptoms Spread all over Santa Fe"
# Found city: "San Luis" in "Zika spreads to San Luis Potosi"
# Found city: "San Juan" in "San Juan reports 1st U.S. Zika-related death amid outbreak"
# Found city: "San Juan" in "Rumors about Hepatitis D Spreading in San Juan Capistrano have been Refuted"
# Found city: "San Francisco" in "Zika Virus Reaches San Francisco"
# Found city: "Bella Vista" in "More Zika patients reported in Bella Vista"
# Found city: "Vienna" in "Will the Mad Cow Outbreak Reach Vienna?"
# Found city: "Albany" in "Rumors about Hepatitis D spreading in Albany have been refuted"
# Found city: "Albany" in "Albany Residents Recieve Respiratory Syncytial Virus vaccine"
# Found city: "Townsville" in "Townsville Zika tests inconclusive"
# Found city: "Sydney" in "Schools in Sydney Closed Due to Respiratory Syncytial Virus Outbreak"
# Found city: "Rockhampton" in "Precautionary Zika measures in Rockhampton"
# Found city: "Richmond" in "Lower Hospitalization in Richmond after Mumps Vaccine becomes Mandatory"
# Found city: "Richmond" in "Authorities are Worried about the Spread of Chickenpox in Richmond"
# Found city: "Palm Beach" in "Zika arrives in West Palm Beach"
# Found city: "Palm Beach" in "Zika Spreads to Palm Beach Gardens"
# Found city: "Orange" in "More Patients in Orange are Getting Diagnosed with Chickenpox"
# Found city: "Orange" in "Zika arrives in Orange City"
# Found city: "Newcastle" in "Will Herpes vaccine help Newcastle?"
# Found city: "Melbourne" in "Case of Hepatitis E Reported in Melbourne"
# Found city: "Melbourne" in "More Zika patients reported in Melbourne"
# Found city: "Kensington" in "More Patients in Kensington are Getting Diagnosed with Varicella"
# Found city: "Gladstone" in "Gladstone Encounters Severe Symptoms of Dengue"
# Found city: "Fairfield" in "Tuberculosis has Arrived in Fairfield"
# Found city: "Fairfield" in "The Spread of West Nile Virus in Fairfield has been Confirmed"
# Found city: "Canberra" in "Spike of Norovirus Cases in Canberra"
# Found city: "Bundaberg" in "Rumors about Bronchitis spreading in Bundaberg have been refuted"
# Found city: "Brisbane" in "Brisbane is infested with Meningitis"
# Found city: "Brighton" in "Rumors about Mad Cow Disease Brighton have been Refuted"
# Found city: "Ganja" in "Authorities are Worried about the Spread of Hepatitis D in Ganja"
# Found city: "Baku" in "The Spread of Herpes in Baku has been Confirmed"
# Found city: "Dhaka" in "Lower Hospitalization in Dhaka after Measles Vaccine becomes Mandatory"
# Found city: "Brussels" in "Mad Cow Disease Disastrous to Brussels"
# Found city: "Hamilton" in "Rabies Exposure in Hamilton"
# Found city: "Trinidad" in "Trinidad confirms first Zika case"
# Found city: "Recife" in "Mystery Virus Spreads in Recife, Brazil"
# Found city: "Olinda" in "Zika spreads to Olinda"
# Found city: "Natal" in "Zika arrives in Natal"
# Found city: "Limoeiro" in "Zika case reported in Limoeiro"
# Found city: "Horizonte" in "New Zika Case Confirmed in Belo Horizonte"
# Found city: "Fortaleza" in "Zika symptoms spotted in Fortaleza"
# Found city: "Toledo" in "Chikungunya Exposure in Toledo"
# Found city: "Santos" in "Zika arrives in Santos"
# Found city: "Santiago" in "How to Avoid Chlamydia in Santiago"
# Found city: "Salvador" in "Zika spreading to Salvador"
# Found city: "Salvador" in "Zika worries in San Salvador"
# Found city: "Sacramento" in "Influenza has not Left Sacramento"
# Found city: "Rio Grande" in "Zika alert for Rio Grande Valley residents"
# Found city: "Piracicaba" in "Zika outbreak in Piracicaba, Brazil"
# Found city: "Orleans" in "Zika only the latest mosquito-borne threat to New Orleans"
# Found city: "Jacobina" in "Zika case reported in Jacobina"
# Found city: "Colombo" in "Zika symptoms spotted in Colombo"
# Found city: "Colombo" in "Outbreak of Zika in Colombo"
# Found city: "Campinas" in "Student sick in Campinas, Brazil"
# Found city: "Botucatu" in "More Zika patients reported in Botucatu"
# Replacing previously found city "Horizonte" in "New Zika Case Confirmed in Belo Horizonte" with "Belo Horizonte"
# Found city: "Manaus" in "Zika Outbreak in Manaus"
# Found city: "Nassau" in "Meningitis re-emerges in Nassau"
# Found city: "Belmopan" in "Zika arrives in Belmopan"
# Found city: "Belize City" in "Belize City under threat from Zika"
# Found city: "Aurora" in "Case of Malaria Reported in Aurora"
# Found city: "Calgary" in "Case of Hepatitis A Reported in Calgary"
# Found city: "Cambridge" in "More Patients in Cambridge are Getting Diagnosed with Chickenpox"
# Found city: "Cambridge" in "Varicella Exposure in Cambridge"
# Found city: "Chatham" in "Mad Cow Disease Re-emerges in Chatham"
# Found city: "Huntsville" in "Rumors about Rotavirus spreading in Huntsville have been refuted"
# Found city: "Kingston" in "Authorities are Worried about the Spread of Dengue in Kingston"
# Found city: "Kingston" in "Herpes Symptoms Spread all over New Kingston"
# Found city: "London" in "London Health Unit Tracks Mad Cow Disease"
# Found city: "London" in "Mad Cow Disease Hits London"
# Found city: "Milton" in "Varicella has Arrived in Milton"
# Found city: "North Bay" in "Authorities are Worried about the Spread of Hepatitis D in North Bay"
# Found city: "North Vancouver" in "Chikungunya Keeps Spreading in North Vancouver"
# Found city: "Ottawa" in "Rumors about Pneumonia spreading in Ottawa have been refuted"
# Found city: "St. Catharines" in "St. Catharines Patient in Critical Condition after Contracting Dengue"
# Found city: "Stratford" in "Case of Norovirus Reported in Stratford"
# Found city: "Terrebonne" in "Malaria has Arrived in Terrebonne"
# Found city: "Toronto" in "More people in Toronto are infected with Hepatitis E every year"
# Found city: "Vancouver" in "Case of Measles Reported in Vancouver"
# Found city: "Windsor" in "Tests negative on Windsor Zika carriers"
# Found city: "Winnipeg" in "Norovirus has Arrived in Winnipeg"
# Found city: "Halifax" in "Halifax is infested with Swine Flu"
# Found city: "Kinshasa" in "Pneumonia has not Left Kinshasa"
# Found city: "Brazzaville" in "The Spread of Malaria in Brazzaville has been Confirmed"
# Found city: "Lausanne" in "Lausanne Residents Recieve Meningitis vaccine"
# Found city: "Basel" in "How to Avoid Contaminated Meat when Visiting Basel"
# Found city: "San Antonio" in "Zika San Antonio Patient Speaks Out"
# Found city: "Wuhan" in "Wuhan is infested with Varicella"
# Found city: "Suzhou" in "Rumors about Swine Flu spreading in Suzhou have been refuted"
# Found city: "Shenzhen" in "Schools in Shenzhen Closed Due to Malaria Outbreak"
# Found city: "Huzhou" in "Huzhou Residents Receive Hepatitis B vaccine"
# Found city: "Guangzhou" in "Guangzhou Patient in Critical Condition after Contracting Swine Flu"
# Found city: "Dongguan" in "West Nile Virus has Arrived in Dongguan"
# Found city: "Yiwu" in "Authorities are Worried about the Spread of Hepatitis B in Yiwu"
# Found city: "Beijing" in "Beijing team cracks Zika secret"
# Found city: "Villavicencio" in "Villavicencio under Zika threat"
# Found city: "Sincelejo" in "Zika Outbreak in Sincelejo"
# Found city: "Sevilla" in "New medicine wipes out Meningitis in Sevilla"
# Found city: "San Onofre" in "Zika arrives in San Onofre"
# Found city: "Madrid" in "Spanish flu spreading in Madrid"
# Found city: "Madrid" in "Rabies Hits Madrid"
# Found city: "Madrid" in "Spanish Flu Spreading through Madrid"
# Found city: "Madrid" in "Spanish Flu Spreading through Madrid"
# Found city: "Fresno" in "New medicine wipes out Measles in Fresno"
# Found city: "Florida" in "Zika Patient in Seminole, Florida"
# Found city: "Florida" in "Zika Mosquitoes May Have Bred in Bromeliads, Florida Officials Say"
# Found city: "Darien" in "Rumors about Hepatitis C spreading in Darien have been refuted"
# Found city: "Caucasia" in "Zika spreads to Caucasia"
# Found city: "Bello" in "Zika symptoms spotted in Bello"
# Found city: "Barranquilla" in "Zika spreads to Barranquilla"
# Found city: "San Diego" in "Key Zika Findings in San Diego Institute"
# Found city: "Havana" in "Zika Virus Transmission Detected in Havana"
# Found city: "Praia" in "Praia tests new cure for Pneumonia"
# Found city: "Pilsen" in "Pilsen Encounters Severe Symptoms of Malaria"
# Found city: "Stuttgart" in "More Patients in Stuttgart are Getting Diagnosed with Rabies"
# Found city: "Hilden" in "Case of Mad Cow Disease Reported in Hilden"
# Found city: "Hamburg" in "Will Meningitis vaccine help Hamburg?"
# Found city: "Duisburg" in "Duisburg up in Arms over Mad Cow Disease"
# Found city: "Cham" in "Zika Troubles come to Kampong Cham"
# Found city: "Bonn" in "Contaminated Meat Brings Trouble for Bonn Farmers"
# Found city: "Berlin" in "Spike of Chlamydia Cases in Berlin"
# Found city: "Copenhagen" in "Norovirus Keeps Spreading in Copenhagen"
# Found city: "Quisqueya" in "Zika symptoms spotted in Quisqueya"
# Found city: "Quito" in "Zika symptoms spotted in Quito"
# Found city: "Portoviejo" in "Outbreak of Zika in Portoviejo"
# Found city: "La Libertad" in "Zika Troubles come to La Libertad"
# Found city: "Aswan" in "Hepatitis D Exposure in Aswan"
# Found city: "Alexandria" in "More Patients in Alexandria are Getting Diagnosed with Mumps"
# Found city: "Murcia" in "Mad Cow case in Murcia"
# Found city: "Salt" in "Salt Lake City tests new cure for Respiratory Syncytial Virus"
# Found city: "Durango" in "Durango is infested with Hepatitis B"
# Found city: "Barcelona" in "Spanish Flu Outbreak in Barcelona"
# Found city: "Barcelona" in "Barcelona Struck by Spanish Flu"
# Found city: "Barcelona" in "Barcelona Struck by Spanish Flu"
# Found city: "Addis Ababa" in "Will Rotavirus vaccine help Addis Ababa?"
# Found city: "Suva" in "Suva authorities confirmed the spread of Rotavirus"
# Found city: "Nadi" in "More people in Nadi are infected with HIV every year"
# Found city: "Labasa" in "Rotavirus Vaccine is now Required in Labasa"
# Found city: "Strasbourg" in "Will MCD vaccine help Strasbourg?"
# Found city: "Paris" in "Scientists in Paris to look for answers"
# Found city: "Montpellier" in "Rumors about HIV spreading in Montpellier have been refuted"
# Found city: "Lyon" in "Mad Cow Disease Detected in Lyon"
# Found city: "Grenoble" in "Hepatitis D has Arrived in Grenoble"
# Found city: "Fontainebleau" in "More Livestock in Fontainebleau are infected with Mad Cow Disease"
# Found city: "Croix" in "Saint Croix under Zika threat"
# Found city: "Belfort" in "Sick Livestock Leads to Serious Trouble for Belfort"
# Found city: "Avon" in "Gonorrhea has Arrived in Avon Lake"
# Found city: "Libreville" in "Hepatitis E has not Left Libreville"
# Found city: "York" in "Could Zika Reach New York City?"
# Found city: "Wellington" in "West Nile Virus re-emerges in Wellington"
# Found city: "Stamford" in "Hepatitis A re-emerges in Stamford"
# Found city: "Southampton" in "Southampton Patient in Critical Condition after Contracting Tuberculosis"
# Found city: "Rochester" in "Rochester authorities confirmed the spread of Dengue"
# Found city: "Rochester" in "Herpes Keeps Spreading in Rochester"
# Found city: "Oxford" in "Oxford tests new cure for HIV"
# Found city: "Margate" in "Mad Cow Disease Spreads to Margate"
# Found city: "Manchester" in "Manchester Residents Recieve Influenza vaccine"
# Found city: "Huddersfield" in "Spike of Norovirus Cases in Huddersfield"
# Found city: "Hampton" in "How to Avoid Chikungunya in Hampton"
# Found city: "Grove" in "How to Avoid Rhinovirus in Lemon Grove"
# Found city: "Glasgow" in "Schools in Glasgow Closed Due to Hepatitis B Outbreak"
# Found city: "Flint" in "Bad Water Leads to Sickness in Flint, Michigan"
# Found city: "Edinburgh" in "Hepatitis B Exposure in Edinburgh"
# Found city: "Edinburgh" in "Authorities are Worried about the Spread of Mad Cow Disease in Edinburgh"
# Found city: "Durham" in "More people in Durham are infected with Chlamydia every year"
# Found city: "Bristol" in "Will Mad Cow Vaccine Help Bristol?"
# Found city: "Boston" in "Flu season hits Boston"
# Found city: "Birmingham" in "Birmingham Residents Recieve Rabies vaccine"
# Found city: "Birmingham" in "Schools in Birmingham Closed Due to Measles Outbreak"
# Found city: "Bedford" in "Rumors about Mumps Spreading in New Bedford have been Refuted"
# Found city: "Bedford" in "More contaminated cattle reported in Bedford"
# Found city: "Bedford" in "Mad Cow Disease re-emerges in Bedford"
# Found city: "Tbilisi" in "Case of Swine Flu Reported in Tbilisi"
# Found city: "Ho" in "Zika cases in Vietnam's Ho Chi Minh City surge"
# Found city: "Athens" in "Rhinovirus has Arrived in Athens"
# Found city: "San Benito" in "Zika arrives in San Benito"
# Found city: "Guatemala City" in "Rumors about Meningitis spreading in Guatemala City have been refuted"
# Found city: "Hong Kong" in "Norovirus Exposure in Hong Kong"
# Found city: "Tegucigalpa" in "Zika arrives in Tegucigalpa"
# Found city: "Yogyakarta" in "West Nile Virus Hits Yogyakarta"
# Found city: "Sengkang" in "19 new Zika Cases in Sengkang"
# Found city: "Pekanbaru" in "Lower Hospitalization in Pekanbaru after Rotavirus Vaccine becomes Mandatory"
# Found city: "Jakarta" in "Zika now spreading through Jakarta"
# Found city: "Dumai" in "Will West Nile Virus vaccine help Dumai?"
# Found city: "Ennis" in "Mad Cow Outbreak Spreading in Ennis"
# Found city: "Dublin" in "More Patients in Dublin are Getting Diagnosed with Bronchitis"
# Found city: "Jerusalem" in "Rumors about Rabies spreading in Jerusalem have been refuted"
# Found city: "Salem" in "Rumors about West Nile Virus Spreading in Salem have been Refuted"
# Found city: "Pune" in "Pune woman diagnosed with Zika"
# Found city: "Puducherry" in "Zika Outbreak in Puducherry"
# Found city: "New Delhi" in "New Delhi Addressing Zika Concerns"
# Found city: "Chennai" in "More Zika patients reported in Chennai"
# Found city: "Kozhikode" in "Outbreak of Zika in Kozhikode"
# Found city: "Kota" in "New Zika Case in Kota Kinabalu, Malaysia"
# Found city: "Hyderabad" in "Zika Outbreak in Hyderabad"
# Found city: "Delhi" in "Zika: Delhi for strict monitoring"
# Found city: "Mumbai" in "Mumbai's Health Minister warns of more Zika cases"
# Found city: "Baud" in "Rumors about Tuberculosis Spreading in Baud have been Refuted"
# Found city: "Greater Noida" in "Zika Troubles come to Greater Noida"
# Found city: "Tehran" in "Bronchitis re-emerges in Tehran"
# Found city: "Rome" in "Authorities are Worried about the Spread of Mad Cow Disease in Rome"
# Found city: "Naples" in "Mad Cow Disease Hits Naples"
# Found city: "Florence" in "Hepatitis B has not Left Florence"
# Replacing previously found city "Kingston" in "Herpes Symptoms Spread all over New Kingston" with "New Kingston"
# Found city: "Yokohama" in "More people in Yokohama are infected with Norovirus every year"
# Found city: "Tokyo" in "Tokyo Encounters Severe Symptoms of Meningitis"
# Found city: "Kobe" in "Chikungunya re-emerges in Kobe"
# Found city: "Fukushima" in "Hepatitis A Vaccine is now Required in Fukushima"
# Found city: "Molo" in "Molo Cholera Spread Causing Concern"
# Found city: "Phnom Penh" in "Phnom Penh hit by Zika Threat"
# Found city: "Kampong Speu" in "More Zika patients reported in Kampong Speu"
# Replacing previously found city "Cham" in "Zika Troubles come to Kampong Cham" with "Kampong Cham"
# Found city: "Pyongyang" in "Authorities are Worried about the Spread of Syphilis in Pyongyang"
# Found city: "Seoul" in "Seoul confirms 14th Zika infection"
# Found city: "Greenville" in "How to Avoid Norovirus in Greenville"
# Found city: "Greenville" in "Spike of Hepatitis B Cases in Greenville"
# Found city: "Tangier" in "Will Rabies vaccine help Tangier?"
# Found city: "Majuro" in "Is Zika virus in Majuro?"
# Found city: "San" in "Rhinovirus Comes to San Jose"
# Found city: "San" in "How to Avoid Respiratory Syncytial Virus in San Bernardino"
# Found city: "San" in "Bronchitis Keeps Spreading in San Mateo"
# Found city: "San" in "Pneumonia Exposure in San Jose"
# Found city: "Yangon" in "First Zika case confirmed in Yangon"
# Found city: "Mandalay" in "Spike of Respiratory Syncytial Virus Cases in Mandalay"
# Found city: "Hinthada" in "HIV Symptoms Spread all over Hinthada"
# Found city: "Veracruz" in "Veracruz hit by Zika Concerns"
# Found city: "Reynosa" in "Zika case reported in Reynosa"
# Found city: "Oaxaca" in "Zika arrives in Oaxaca"
# Found city: "Nuevo Laredo" in "More Zika patients reported in Nuevo Laredo"
# Found city: "Mexico City" in "Zika outbreak spreads to Mexico City"
# Found city: "Mexicali" in "Zika Outbreak in Mexicali"
# Found city: "Medina" in "Meningitis re-emerges in Medina"
# Found city: "Madera" in "Madera Patient in Critical Condition after Contracting Rabies"
# Found city: "Hidalgo" in "Four cases of Zika in Hidalgo County"
# Found city: "Johor Bahru" in "Zika reaches Johor Bahru, Malaysia"
# Found city: "Klang" in "Zika surfaces in Klang, Malaysia"
# Replacing previously found city "Kota" in "New Zika Case in Kota Kinabalu, Malaysia" with "Kota Kinabalu"
# Found city: "Petaling Jaya" in "Petaling Jaya man ill from Zika"
# Found city: "Kuala Lumpur" in "Kuala Lumpur is Hit By Zika Threat"
# Found city: "Kuching" in "Zika spreads to Kuching"
# Found city: "Sibu" in "Zika symptoms spotted in Sibu"
# Found city: "Miri" in "Zika arrives in Miri"
# Found city: "Lagos" in "Varicella re-emerges in Lagos"
# Found city: "Ibadan" in "Vericella spreading in Ibadan"
# Found city: "Ibadan" in "Ibadan tests new cure for Malaria"
# Found city: "Abuja" in "Authorities are Worried about the Spread of Tuberculosis in Abuja"
# Found city: "Masaya" in "Respiratory Syncytial Virus Keeps Spreading in Masaya"
# Found city: "Managua" in "Spike of Rabies Cases in Managua"
# Found city: "Rotterdam" in "Mad Cow Disease Hits Rotterdam"
# Found city: "Harlingen" in "Zika Troubles come to Harlingen"
# Found city: "Kathmandu" in "Dengue Exposure in Kathmandu"
# Found city: "Auckland" in "Lower Hospitalization in Auckland after Hepatitis D Vaccine becomes Mandatory"
# Found city: "Muscat" in "Influenza Exposure in Muscat"
# Found city: "Tocumen" in "Tocumen tests new cure for Hepatitis A"
# Found city: "Las Cumbres" in "Rotavirus Vaccine is now Required in Las Cumbres"
# Found city: "Yurimaguas" in "Zika Outbreak in Yurimaguas"
# Found city: "Laredo" in "Two more Zika cases confirmed in Laredo"
# Found city: "Iquitos" in "Zika symptoms spotted in Iquitos"
# Found city: "Lima" in "Lima tries to address Zika Concerns"
# Found city: "Imperial" in "The Spread of Meningitis in Imperial has been Confirmed"
# Found city: "Papeete" in "Lower Hospitalization in Papeete after Measles Vaccine becomes Mandatory"
# Found city: "Zamboanga" in "Sulu, Zamboanga brace for Zika"
# Found city: "Santa Barbara" in "Santa Barbara tests new cure for Hepatitis C"
# Replacing previously found city "San" in "Bronchitis Keeps Spreading in San Mateo" with "San Mateo"
# Replacing previously found city "San" in "Rhinovirus Comes to San Jose" with "San Jose"
# Replacing previously found city "San" in "Pneumonia Exposure in San Jose" with "San Jose"
# Found city: "Rizal" in "Zika case reported in Rizal"
# Found city: "Quezon City" in "More Quezon City Zika Transmissions"
# Found city: "Quezon" in "Zika arrives in Quezon"
# Found city: "Palo" in "More people in Palo Alto are infected with HIV every year"
# Found city: "Manila" in "Zika alert aEUR" Manila now threatened"
# Found city: "Mandaluyong City" in "Mandaluyong City under Siege by Virus"
# Found city: "Jaen" in "Zika Troubles come to Jaen"
# Found city: "Indang" in "More Zika patients reported in Indang"
# Found city: "Iloilo" in "Zika afflicts 7 in Iloilo City"
# Found city: "Davao" in "More Zika patients reported in Davao"
# Found city: "Calumpang" in "More Zika patients reported in Calumpang"
# Found city: "Calamba" in "Zika afflicts patient in Calamba"
# Found city: "Bay" in "Tampa Bay Area Zika Case Count Climbs"
# Found city: "Batangas" in "Batangas Tourism Takes a Hit as Virus Spreads"
# Found city: "Bacoor" in "Spreading Zika reaches Bacoor"
# Found city: "Bacolod City" in "Outbreak of Zika in Bacolod City"
# Found city: "Antipolo" in "Antipolo under threat from Zika Virus"
# Found city: "Pasig City" in "Outbreak of Zika in Pasig City"
# Found city: "Caguas" in "Tuberculosis Symptoms Spread all over Caguas"
# Found city: "Bethlehem" in "Hepatitis C Outbreak in Bethlehem"
# Found city: "Lisbon" in "Spanish Flu Outbreak in Lisbon"
# Found city: "Lisbon" in "Spanish Flu Outbreak in Lisbon"
# Found city: "Pedro Juan Caballero" in "Pedro Juan Caballero Encounters Severe Symptoms of Pneumonia"
# Found city: "Sochi" in "Will Measles vaccine help Sochi?"
# Found city: "Saint Petersburg" in "More people in Saint Petersburg are infected with Varicella every year"
# Found city: "Moscow" in "Lung Cancer Rates Increasing in Moscow"
# Found city: "Mecca" in "Mecca tests new cure for Chikungunya"
# Found city: "Khartoum" in "Rumors about Rabies Spreading in Khartoum have been Refuted"
# Found city: "Stockholm" in "Spike of Dengue Cases in Stockholm"
# Found city: "Singapore" in "Zika cases in Singapore reach 393"
# Found city: "Ljubljana" in "Will Swine Flu vaccine help Ljubljana?"
# Found city: "Dakar" in "Cholera outbreak in Dakar"
# Found city: "Soyapango" in "More Zika cases in Soyapango"
# Replacing previously found city "Salvador" in "Zika worries in San Salvador" with "San Salvador"
# Found city: "Ilopango" in "Zika Reported in Ilopango"
# Found city: "Damascus" in "Hepatitis C re-emerges in Damascus"
# Found city: "Trang" in "Nha Trang Zika Outbreak"
# Found city: "Kamphaeng Phet" in "Zika spreads to Kamphaeng Phet"
# Found city: "Udon Thani" in "Zika arrives in Udon Thani"
# Found city: "Phetchabun" in "Zika case reported in Phetchabun"
# Found city: "Bangkok" in "Thailand-Zika Virus in Bangkok"
# Found city: "Chanthaburi" in "More Zika patients reported in Chanthaburi"
# Found city: "Tunapuna" in "Zika case recorded in Tunapuna A>>"
# Found city: "Sangre Grande" in "Sangre Grande Residents Recieve Gonorrhea vaccine"
# Found city: "Laventille" in "Laventille authorities confirmed the spread of Rhinovirus"
# Found city: "Taipei" in "New medicine wipes out Tuberculosis in Taipei"
# Found city: "Taoyuan City" in "Authorities are Worried about the Spread of Gonorrhea in Taoyuan City"
# Found city: "Zanzibar" in "The Spread of Malaria in Zanzibar has been Confirmed"
# Found city: "Zanzibar" in "Malaria Outbreak Hits Zanzibar's Tourist Industry"
# Found city: "Arusha" in "Tourist Perishes from Malaria in Arusha"
# Found city: "Kampala" in "Ebola outbreak in Kampala"
# Found city: "Entebbe" in "Lower Hospitalization in Entebbe after Rabies Vaccine becomes Mandatory"
# Found city: "Madison" in "Madison lab developing vaccine against Zika virus [The Wisconsin State Journal]"
# Found city: "Mobile" in "Mobile authorities confirmed the spread of Bronchitis"
# Found city: "Benton" in "Benton Residents Recieve Pneumonia vaccine"
# Found city: "Bentonville" in "Schools in Bentonville Closed Due to Hepatitis B Outbreak"
# Found city: "Fayetteville" in "Fayetteville authorities confirmed the spread of HIV"
# Found city: "Jacksonville" in "Jacksonville man hit by Zika"
# Found city: "Springdale" in "Case of Measles Reported in Springdale"
# Found city: "Newark" in "Tuberculosis Outbreak in Newark"
# Found city: "Boca Raton" in "Zika arrives in Boca Raton"
# Found city: "Bonita Springs" in "Zika symptoms spotted in Bonita Springs"
# Found city: "Boynton Beach" in "Zika symptoms spotted in Boynton Beach"
# Found city: "Bradenton" in "Bradenton Experiences Zika Troubles"
# Found city: "Brownsville" in "Brownsville teen contracts Zika virus"
# Found city: "Coral Gables" in "Zika case reported in Coral Gables"
# Found city: "Daytona Beach" in "Zika spreads to Daytona Beach"
# Found city: "Delray Beach" in "Zika Troubles come to Delray Beach"
# Found city: "Doral" in "Doral hit by Deadly Virus"
# Found city: "Fort Lauderdale" in "Spring break ruined by Zika in Fort Lauderdale"
# Found city: "Fort Myers" in "More Zika patients reported in Fort Myers"
# Found city: "Fort Pierce" in "Zika reported in Fort Pierce"
# Found city: "Gainesville" in "Gainesville Deals with Disease Concerns"
# Found city: "Hallandale Beach" in "Hallandale Beach a Victim of Zika Outbreak"
# Found city: "Hollywood" in "Hollywood Outbreak Film Premieres"
# Found city: "Hollywood" in "Zika symptoms spotted in Hollywood"
# Found city: "Jupiter" in "Zika case reported in Jupiter"
# Found city: "Key West" in "Zika symtomps spotted in Key West"
# Found city: "Kissimmee" in "Zika spreads to Kissimmee"
# Found city: "Lakeland" in "More Zika patients reported in Lakeland"
# Found city: "Leesburg" in "Outbreak of Zika in Leesburg"
# Found city: "Miami" in "Zika Outbreak Hits Miami"
# Found city: "Miami" in "First Case of Zika in Miami Beach"
# Found city: "Miami" in "Zika Arrives in North Miami"
# Found city: "Miami" in "Miami resident suggests Zika precautions"
# Found city: "Miami" in "Authorities a Miami"
# Found city: "Miami" in "Zika Outbreak in South Miami"
# Found city: "Miami" in "Zika Reported in North Miami Beach"
# Replacing previously found city "Miami" in "First Case of Zika in Miami Beach" with "Miami Beach"
# Replacing previously found city "Miami" in "Zika Reported in North Miami Beach" with "Miami Beach"
# Replacing previously found city "Miami" in "Zika Arrives in North Miami" with "North Miami"
# Replacing previously found city "Miami Beach" in "Zika Reported in North Miami Beach" with "North Miami Beach"
# Found city: "Orlando" in "Orlando volunteers aid Zika research"
# Replacing previously found city "Palm Beach" in "Zika Spreads to Palm Beach Gardens" with "Palm Beach Gardens"
# Found city: "Palm Springs" in "Outbreak of Zika in Palm Springs"
# Found city: "Palm Springs" in "Lower Hospitalization in Palm Springs after Hepatitis A Vaccine becomes Mandatory"
# Found city: "Panama City" in "Outbreak of Zika in Panama City"
# Found city: "Pensacola" in "More Zika patients reported in Pensacola"
# Found city: "Pinewood" in "Zika Outbreak in Pinewood"
# Found city: "Plant City" in "Zika spreads to Plant City"
# Found city: "Princeton" in "Princeton Encounters Severe Symptoms of Dengue"
# Found city: "St. Petersburg" in "Zika Strikes St. Petersburg"
# Found city: "Sarasota" in "New Zika Case Confirmed in Sarasota County"
# Replacing previously found city "Florida" in "Zika Patient in Seminole, Florida" with "Seminole"
# Found city: "Tallahassee" in "Tallahassee Doctors Discuss Zika Virus"
# Found city: "Tamarac" in "Zika in Tamarac!"
# Replacing previously found city "Bay" in "Tampa Bay Area Zika Case Count Climbs" with "Tampa"
# Found city: "Vero Beach" in "Can Zika make it here to Vero Beach?"
# Replacing previously found city "Palm Beach" in "Zika arrives in West Palm Beach" with "West Palm Beach"
# Found city: "Westchester" in "Zika virus confirmed in Westchester"
# Found city: "Winter Park" in "Zika spreads to Winter Park"
# Found city: "Alpharetta" in "West Nile Virus Exposure in Alpharetta"
# Found city: "Atlanta" in "The CDC in Atlanta is Growing Worried"
# Found city: "Canton" in "More Patients in Canton are Getting Diagnosed with Norovirus"
# Found city: "Carrollton" in "More Zika patients reported in Carrollton"
# Found city: "Columbus" in "First Columbus Zika case"
# Found city: "Duluth" in "Duluth Patient in Critical Condition after Contracting Rotavirus"
# Found city: "Lawrenceville" in "Lawrenceville is infested with Dengue"
# Found city: "Savannah" in "Authorities are Worried about the Spread of Influenza in Savannah"
# Found city: "Valdosta" in "Zika battle outlined at Valdosta meeting"
# Found city: "Mattoon" in "Herpes Vaccine is now Required in Mattoon"
# Found city: "Springfield" in "Spike of Pneumonia Cases in Springfield"
# Found city: "Bloomington" in "Pneumonia Symptoms Spread all over Bloomington"
# Found city: "Evansville" in "Hepatitis D Symptoms Spread all over Evansville"
# Found city: "Indianapolis" in "More people in Indianapolis are infected with Norovirus every year"
# Found city: "Plainfield" in "How to Avoid Rhinovirus in Plainfield"
# Found city: "Kansas City" in "Hepatitis B Comes to Kansas City"
# Found city: "Manhattan" in "Manhattan Residents Recieve HIV vaccine"
# Found city: "Wichita" in "Zika Outbreak in Wichita Falls"
# Found city: "Danville" in "Schools in Danville Closed Due to Tuberculosis Outbreak"
# Found city: "Henderson" in "Respiratory Syncytial Virus Hits Henderson"
# Found city: "Louisville" in "West Nile Virus Outbreak in Louisville"
# Found city: "Baton Rouge" in "New details in Baton Rouge cop killings"
# Found city: "Bossier City" in "New medicine wipes out Herpes in Bossier City"
# Found city: "Hammond" in "Hepatitis E Hits Hammond"
# Found city: "Lafayette" in "Is Lafayette prepared to combat Zika?"
# Found city: "Monroe" in "Lower Hospitalization in Monroe after Hepatitis D Vaccine becomes Mandatory"
# Found city: "Monroe" in "Spike of Syphilis Cases in West Monroe"
# Found city: "Monroe" in "West Nile Virus Hits Monroe"
# Found city: "Monroe" in "The Spread of Respiratory Syncytial Virus in Monroe has been Confirmed"
# Replacing previously found city "Orleans" in "Zika only the latest mosquito-borne threat to New Orleans" with "New Orleans"
# Found city: "Shreveport" in "How to Avoid Gonorrhea in Shreveport"
# Found city: "Annapolis" in "Will Swine Flu vaccine help Annapolis?"
# Found city: "Baltimore" in "Baltimore plans for Zika virus"
# Found city: "Bethesda" in "New Vaccine on Trial in Bethesda District"
# Found city: "Bethesda" in "Hepatitis D Symptoms Spread all over North Bethesda"
# Found city: "Easton" in "Dengue Outbreak in Easton"
# Found city: "Gaithersburg" in "Case of Chikungunya Reported in Gaithersburg"
# Found city: "Germantown" in "Germantown authorities confirmed the spread of Chickenpox"
# Replacing previously found city "Bethesda" in "Hepatitis D Symptoms Spread all over North Bethesda" with "North Bethesda"
# Found city: "Rockville" in "Will Tuberculosis vaccine help Rockville?"
# Found city: "Saint Charles" in "New medicine wipes out Mumps in Saint Charles"
# Found city: "Silver Spring" in "Authorities are Worried about the Spread of Bronchitis in Silver Spring"
# Found city: "Waldorf" in "How to Avoid Hepatitis B in Waldorf"
# Found city: "Concord" in "Case of Varicella Reported in Concord"
# Found city: "Farmington" in "Spike of Chlamydia Cases in Farmington"
# Found city: "Joplin" in "Mumps Outbreak in Joplin"
# Found city: "St. Louis" in "Mosquito control efforts in St. Louis take new tactics with Zika threat"
# Found city: "University City" in "Chlamydia Symptoms Spread all over University City"
# Found city: "Biloxi" in "Biloxi Residents Recieve Chlamydia vaccine"
# Found city: "Starkville" in "Rotavirus Vaccine is now Required in Starkville"
# Found city: "Tupelo" in "Tupelo Residents Recieve Syphilis vaccine"
# Found city: "Charlotte" in "Zika cases concern Charlotte residents"
# Found city: "Raleigh" in "Will Norovirus vaccine help Raleigh?"
# Found city: "Bridgeton" in "Schools in Bridgeton Closed Due to Mumps Outbreak"
# Found city: "Toms River" in "Toms River Encounters Severe Symptoms of Respiratory Syncytial Virus"
# Found city: "Vineland" in "Vineland authorities confirmed the spread of Chlamydia"
# Found city: "Cincinnati" in "First Zika Case in Cincinnati"
# Found city: "Dayton" in "Case of Mumps Reported in Dayton"
# Found city: "Riverside" in "Case of West Nile Virus Reported in Riverside"
# Found city: "Altus" in "Rabies Outbreak in Altus"
# Found city: "Ardmore" in "Zika-carrying mosquitoes discovered in Ardmore"
# Found city: "Stillwater" in "Chickenpox Comes to Stillwater"
# Found city: "Tulsa" in "Respiratory Syncytial Virus Vaccine is now Required in Tulsa"
# Found city: "Philadelphia" in "Philadelphia experts track pandemic"
# Found city: "Simpsonville" in "Chickenpox Hits Simpsonville"
# Found city: "Summerville" in "Meningitis re-emerges in Summerville"
# Found city: "Cleveland" in "Zika virus reported in Cleveland"
# Found city: "Memphis" in "Memphis Encounters Severe Symptoms of Swine Flu"
# Found city: "Morristown" in "Rumors about Hepatitis E Spreading in Morristown have been Refuted"
# Found city: "Nashville" in "Nashville takes precautions against Zika"
# Found city: "Sevierville" in "Spike of Rhinovirus Cases in Sevierville"
# Found city: "Abilene" in "Zika case reported in Abilene"
# Found city: "Arlington" in "Zika symptoms spotted in Arlington"
# Found city: "Austin" in "More Zika patients reported in Austin"
# Found city: "Corpus Christi" in "Outbreak of Zika in Corpus Christi"
# Found city: "Dallas" in "Dallas man comes down with case of Zika"
# Found city: "Fort Worth" in "More Zika patients reported in Fort Worth"
# Found city: "Frisco" in "Frisco Woman Tests Positive For Zika Virus"
# Found city: "Galveston" in "Flu outbreak in Galveston, Texas"
# Found city: "Houston" in "Zika Concerns are Spreading in Houston"
# Found city: "Lewisville" in "Zika spreads to Lewisville"
# Found city: "Saginaw" in "New medicine wipes out Dengue in Saginaw"
# Found city: "Stephenville" in "Outbreak of Zika in Stephenville"
# Found city: "Waco" in "More Zika patients reported in Waco"
# Found city: "Weslaco" in "Zika Outbreak in Weslaco"
# Replacing previously found city "Wichita" in "Zika Outbreak in Wichita Falls" with "Wichita Falls"
# Found city: "Fairfax" in "HIV has Arrived in Fairfax"
# Found city: "Jefferson" in "Syphilis Hits Jefferson"
# Found city: "Jefferson" in "Mumps Symptoms Spread all over Jefferson"
# Found city: "Manassas" in "Manassas Encounters Severe Symptoms of Measles"
# Found city: "Norfolk" in "Norfolk tests new cure for Herpes"
# Found city: "Suffolk" in "Influenza Keeps Spreading in Suffolk"
# Found city: "Huntington" in "Schools in Huntington Closed Due to Rotavirus Outbreak"
# Found city: "Danbury" in "Hepatitis C Outbreak in Danbury"
# Found city: "Hartford" in "Tuberculosis Outbreak in Hartford"
# Found city: "Meriden" in "Spike of Herpes Cases in Meriden"
# Found city: "Milford" in "Will Measles vaccine help Milford?"
# Found city: "Milford" in "New Milford Patient in Critical Condition after Contracting Respiratory Syncytial Virus"
# Found city: "Norwalk" in "Norwalk Encounters Severe Symptoms of Malaria"
# Found city: "Norwalk" in "Gonorrhea Exposure in Norwalk"
# Found city: "Storrs" in "Rhinovirus re-emerges in Storrs"
# Found city: "Davenport" in "Davenport is infested with Dengue"
# Found city: "Iowa City" in "Iowa City Encounters Severe Symptoms of Rhinovirus"
# Found city: "Bridgeport" in "Bridgeport authorities confirmed the spread of West Nile Virus"
# Found city: "Chicago" in "Chicago's First Zika Case Confirmed"
# Found city: "Deerfield" in "Deerfield tests new cure for Measles"
# Found city: "East Moline" in "Will Gonorrhea vaccine help East Moline?"
# Found city: "Joliet" in "Rumors about Rotavirus Spreading in Joliet have been Refuted"
# Found city: "Lansing" in "The Spread of Hepatitis E in Lansing has been Confirmed"
# Found city: "Urbana" in "Urbana Encounters Severe Symptoms of Meningitis"
# Found city: "Crawfordsville" in "More Patients in Crawfordsville are Getting Diagnosed with Rabies"
# Found city: "South Bend" in "How to Avoid Hepatitis E in South Bend"
# Found city: "Belmont" in "Zika in Belmont, Belmont worry"
# Found city: "Danvers" in "Hepatitis D Keeps Spreading in Danvers"
# Found city: "Framingham" in "Framingham Residents Receive Measles vaccine"
# Found city: "Medford" in "How to Avoid Rhinovirus in Medford"
# Replacing previously found city "Bedford" in "Rumors about Mumps Spreading in New Bedford have been Refuted" with "New Bedford"
# Found city: "Rockland" in "Zika virus case reported in Rockland"
# Found city: "Detroit" in "Varicella Keeps Spreading in Detroit"
# Found city: "Marquette" in "Marquette tests new cure for Hepatitis A"
# Found city: "Trenton" in "How to Avoid Hepatitis B in Trenton"
# Found city: "Mankato" in "Zika investigators coming to Mankato"
# Found city: "Northfield" in "Northfield Encounters Severe Symptoms of Herpes"
# Found city: "Winona" in "Malaria Vaccine is now Required in Winona"
# Found city: "Fargo" in "The Spread of Hepatitis E in Fargo has been Confirmed"
# Found city: "Fremont" in "Herpes Symptoms Spread all over Fremont"
# Found city: "Omaha" in "Spike of Rotavirus Cases in Omaha"
# Found city: "Nashua" in "Malaria re-emerges in Nashua"
# Found city: "Cranford" in "More people in Cranford are infected with Hepatitis A every year"
# Found city: "Lakewood" in "Lower Hospitalization in Lakewood after Hepatitis B Vaccine becomes Mandatory"
# Replacing previously found city "Milford" in "New Milford Patient in Critical Condition after Contracting Respiratory Syncytial Virus" with "New Milford"
# Found city: "Union" in "Authorities are Worried about the Spread of Rotavirus in Union"
# Found city: "The Bronx" in "Spike of Pneumonia Cases in The Bronx"
# Found city: "Brooklyn" in "Measles has not Left Brooklyn"
# Found city: "Corona" in "Authorities are Worried about the Spread of Mumps in Corona"
# Found city: "Hauppauge" in "West Nile Virus Keeps Spreading in Hauppauge"
# Found city: "Howard Beach" in "Mumps Hits Howard Beach"
# Found city: "Ithaca" in "Ithaca is infested with Dengue"
# Replacing previously found city "York" in "Could Zika Reach New York City?" with "New York City"
# Found city: "Newburgh" in "New medicine wipes out Rabies in Newburgh"
# Found city: "Ronkonkoma" in "Ronkonkoma is infested with Chickenpox"
# Found city: "Schenectady" in "Malaria Vaccine is now Required in Schenectady"
# Found city: "Staten Island" in "Hepatitis A has not Left Staten Island"
# Found city: "Syracuse" in "Rumors about Dengue Spreading in Syracuse have been Refuted"
# Found city: "Akron" in "Authorities are Worried about the Spread of Hepatitis D in Akron"
# Replacing previously found city "Avon" in "Gonorrhea has Arrived in Avon Lake" with "Avon Lake"
# Found city: "Boardman" in "The Spread of Rhinovirus in Boardman has been Confirmed"
# Found city: "Elyria" in "Malaria Vaccine is now Required in Elyria"
# Found city: "Kent" in "Kent is infested with Rabies"
# Found city: "Lorain" in "Zika case confirmed in Lorain"
# Found city: "Allentown" in "More people in Allentown are infected with Chlamydia every year"
# Found city: "Erie" in "Erie County sets Zika traps"
# Found city: "Harrisburg" in "Syphilis Outbreak in Harrisburg"
# Found city: "Pittsburgh" in "Pittsburgh Residents Recieve Norovirus vaccine"
# Found city: "Scranton" in "Scranton authorities confirmed the spread of Gonorrhea"
# Found city: "Providence" in "Providence Encounters Severe Symptoms of Dengue"
# Found city: "Janesville" in "Lower Hospitalization in Janesville after Varicella Vaccine becomes Mandatory"
# Found city: "Milwaukee" in "Milwaukee authorities confirmed the spread of Rhinovirus"
# Found city: "Racine" in "West Nile Virus Exposure in Racine"
# Found city: "Wisconsin Rapids" in "Wisconsin Rapids Patient in Critical Condition after Contracting Chickenpox"
# Found city: "Bullhead City" in "How to Avoid Pneumonia in Bullhead City"
# Found city: "Phoenix" in "Phoenix Residents Recieve Syphilis vaccine"
# Found city: "Tucson" in "New medicine wipes out Chikungunya in Tucson"
# Found city: "Yuma" in "Zika seminars in Yuma County"
# Found city: "Alameda" in "Alameda Residents Recieve Rabies vaccine"
# Found city: "Alhambra" in "Pneumonia Exposure in Alhambra"
# Found city: "Anaheim" in "Norovirus Vaccine is now Required in Anaheim"
# Found city: "Arcadia" in "The Spread of Chikungunya in Arcadia has been Confirmed"
# Found city: "Bakersfield" in "Rhinovirus Hits Bakersfield"
# Found city: "Barstow" in "Barstow Patient in Critical Condition after Contracting Herpes"
# Found city: "Berkeley" in "More people in Berkeley are infected with Swine Flu every year"
# Found city: "Carlsbad" in "Rumors about Varicella spreading in Carlsbad have been refuted"
# Found city: "Chula Vista" in "Chickenpox has Arrived in Chula Vista"
# Found city: "Clovis" in "Authorities are Worried about the Spread of Varicella in Clovis"
# Found city: "Coronado" in "Will West Nile Virus vaccine help Coronado?"
# Found city: "Escondido" in "Escondido neighborhood to get sprayed for Zika virus"
# Found city: "Foster City" in "Hepatitis A re-emerges in Foster City"
# Found city: "Hayward" in "Bronchitis Keeps Spreading in Hayward"
# Found city: "Hemet" in "Authorities are Worried about the Spread of Chickenpox in Hemet"
# Found city: "La Jolla" in "Swine Flu re-emerges in La Jolla"
# Replacing previously found city "Grove" in "How to Avoid Rhinovirus in Lemon Grove" with "Lemon Grove"
# Found city: "Los Angeles" in "New Los Angeles Hairstyle goes Viral"
# Found city: "Ontario" in "Zika Virus Arrives in Ontario"
# Replacing previously found city "Palo" in "More people in Palo Alto are infected with HIV every year" with "Palo Alto"
# Found city: "Redlands" in "New medicine wipes out Influenza in Redlands"
# Replacing previously found city "San" in "How to Avoid Respiratory Syncytial Virus in San Bernardino" with "San Bernardino"
# Replacing previously found city "San Juan" in "Rumors about Hepatitis D Spreading in San Juan Capistrano have been Refuted" with "San Juan Capistrano"
# Found city: "Santa Monica" in "How to Avoid Tuberculosis in Santa Monica"
# Found city: "Tulare" in "Schools in Tulare Closed Due to Mumps Outbreak"
# Found city: "Ventura" in "New medicine wipes out West Nile Virus in Ventura"
# Found city: "Arvada" in "Arvada is infested with Syphilis"
# Found city: "Denver" in "Chikungunya Hits Denver"
# Found city: "Golden" in "Spike of Hepatitis C Cases in Golden"
# Found city: "Albuquerque" in "Spike of Tuberculosis Cases in Albuquerque"
# Found city: "Las Vegas" in "Will HIV vaccine help Las Vegas?"
# Found city: "Reno" in "The Spread of Gonorrhea in Reno has been Confirmed"
# Found city: "Sparks" in "Zika Virus Sparks 'International Concern'"
# Found city: "El Paso" in "El Paso fighting Zika"
# Found city: "Lubbock" in "Zika Virus Detected in Lubbock"
# Found city: "Boulder" in "HIV Keeps Spreading in Boulder"
# Found city: "Fort Collins" in "Fort Collins Encounters Severe Symptoms of Gonorrhea"
# Found city: "Boise" in "Malaria re-emerges in Boise"
# Found city: "Missoula" in "BREAKING aEUR" Zika in Missoula"
# Found city: "Bismarck" in "Hepatitis D Keeps Spreading in Bismarck"
# Found city: "Minot" in "Varicella Outbreak in Minot"
# Found city: "North Platte" in "Rumors about Rotavirus spreading in North Platte have been refuted"
# Found city: "Redmond" in "Rumors about Chlamydia spreading in Redmond have been refuted"
# Found city: "Ogden" in "Ogden is infested with Gonorrhea"
# Replacing previously found city "Salt" in "Salt Lake City tests new cure for Respiratory Syncytial Virus" with "Salt Lake City"
# Found city: "Springville" in "Pneumonia Outbreak in Springville"
# Found city: "Richland" in "Richland Center is infested with Hepatitis B"
# Found city: "Seattle" in "Seattle scientists get $500,000 grant to pursue Zika vaccine New 7:50 pm"
# Found city: "Spokane" in "The Spread of Measles in Spokane has been Confirmed"
# Found city: "Tacoma" in "HIV has Arrived in Tacoma"
# Found city: "Yakima" in "The Spread of Dengue in Yakima has been Confirmed"
# Found city: "Wailuku" in "Measles Vaccine is now Required in Wailuku"
# Found city: "University" in "Stony Brook University experts discuss Zika virus"
# Found city: "Fort Hood" in "Fort Hood Reports its First Zika Patient"
# Found city: "Montevideo" in "Montevideo Encounters Severe Symptoms of Rotavirus"
# Found city: "Caracas" in "Caracas patient dies"
# Replacing previously found city "Croix" in "Saint Croix under Zika threat" with "Saint Croix"
# Replacing previously found city "Ho" in "Zika cases in Vietnam's Ho Chi Minh City surge" with "Ho Chi Minh City"
# Replacing previously found city "Trang" in "Nha Trang Zika Outbreak" with "Nha Trang"
# Found city: "Hanoi" in "Hospitals in Hanoi fill up with Zika patients"
# Found city: "Sanaa" in "Chlamydia Exposure in Sanaa"
# Found city: "Springs" in "Tuberculosis re-emerges in Silver Springs"
# Found city: "Johannesburg" in "Malaria is Spreading in Johannesburg"
# Found city: "Johannesburg" in "Johannesburg Patient in Critical Condition after Contracting Pneumonia"
# Found city: "Mpika" in "Mpika authorities confirmed the spread of Chikungunya"
# Found city: "Kitwe" in "More people in Kitwe are infected with Respiratory Syncytial Virus every year"
# Found city: "Harare" in "Harare is infested with Pneumonia"
#
# Executed v2 in 19.301241800000007 seconds

# %%
columns = ["headline","countries","cities"]
df = pd.DataFrame.from_records(result_v2, columns=columns)
df.head()
# Out:
#                                   headline countries         cities
# 0                 Zika Outbreak Hits Miami      None          Miami
# 1          Could Zika Reach New York City?      None  New York City
# 2        First Case of Zika in Miami Beach      None    Miami Beach
# 3  Mystery Virus Spreads in Recife, Brazil    Brazil         Recife
# 4  Dallas man comes down with case of Zika      None         Dallas
